# %%
#https://platform.openai.com/docs/guides/tools-web-search

import os
from dotenv import load_dotenv
load_dotenv(override=True)  # Loads the .env file
from openai import OpenAI
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])


response = client.responses.create(
    model="gpt-4.1-mini",
    tools=[{"type": "web_search"}],
    input="What was a positive news story from today?"
)

print(response.output_text)
# Out:
# A recent study published in the journal JAMA Network Open found that taking a one-week break from social media significantly reduced symptoms of anxiety, depression, and insomnia among young adults. The study involved 295 volunteers aged 18 to 24, who decreased their social media usage from nearly two hours to about half an hour per day. Participants reported notable improvements in mental health after the break. ([kffhealthnews.org](https://kffhealthnews.org/morning-briefing/tuesday-november-25-2025/?utm_source=openai))
#
# This finding highlights the potential mental health benefits of reducing social media engagement, especially for younger individuals.
